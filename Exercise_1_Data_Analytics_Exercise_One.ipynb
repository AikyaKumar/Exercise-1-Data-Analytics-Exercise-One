# %% [markdown]
# <a href="https://colab.research.google.com/github/AikyaKumar/Exercise-1-Data-Analytics-Exercise-One/blob/main/Exercise_1_Data_Analytics_Exercise_One.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the two Python libraries.

import pandas as pd
import numpy as np

# %%
# Displaying the first 10 entries of SAS-Dataset. I worked on this dataset for my SAS Final Presentation and I wanted to continue working with the same dataset.
from google.colab import files # Importing 'files' module.
uploaded = files.upload() # Calling 'upload()' function from 'files' module.
df=pd.read_csv("student_lifestyle_dataset.csv") # SAS-Dataset is read into pandas DataFrame using read_csv() function from pandas library.
df.head(10) # Diaplays the first 10 entries using head() method of df.
# I'm displaying the contents in the dataset so that the viewer knows what to expect further.
# Out:
#      <input type="file" id="files-df311f5e-a0b3-40e9-8fcb-db4ef276f2d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-df311f5e-a0b3-40e9-8fcb-db4ef276f2d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Performing Descriptive Statistical Alalysis on Drug Experimentation column from the dataset.

print(f"Mean of Study Hours Per Day is {round(df['Study_Hours_Per_Day'].mean(),2)} hours.")


print(f"Median of Study Hours Per Day is {round(df['Study_Hours_Per_Day'].mean(),2)} hours.")


print(f"Mode of Study Hours Per Day is {round(df['Study_Hours_Per_Day'].mean(),2)} hours.")


print(f"Variance of Study Hours Per Day {round(df['Study_Hours_Per_Day'].mean(),2)}.")


print(f"Standard Deviation of Study Hours Per Day is {round(df['Study_Hours_Per_Day'].mean(),2)} hours.")


print(f"Range of Study Hours Per Day is {df['Study_Hours_Per_Day'].max()-df['Study_Hours_Per_Day'].min()} hours.")
# Out:
# Mean of Study Hours Per Day is 7.48 hours.
# Median of Study Hours Per Day is 7.48 hours.
# Mode of Study Hours Per Day is 7.48 hours.
# Variance of Study Hours Per Day 7.48.
# Standard Deviation of Study Hours Per Day is 7.48 hours.
# Range of Study Hours Per Day is 5.0 hours.

# %%
plt.figure(figsize=(10, 10))
# Creating visualizations.

plt.figure(figsize=(15, 5))

plt.subplot(1, 4, 1)
plt.hist(df['GPA'], bins=10, color="pink", alpha=0.8, edgecolor="blue")
plt.title("Histogram of GPA of Students")
plt.xlabel("GPA")
plt.ylabel("Frequency")

plt.subplot(1, 4, 2)
plt.boxplot(df['Extracurricular_Hours_Per_Day'], vert=False)
plt.title("Box Plot for Extracurricular Hours Per Day")
plt.xlabel("Extracurricular Hours Per Day of a Student")

plt.subplot(1, 4, 3)
plt.plot(df['Social_Hours_Per_Day'], color="blue")
plt.title("Line graph for Social Hours Per Day")
plt.xlabel("Number of Students")
plt.ylabel("Social Hours Per Day")

plt.subplot(1, 4, 4)
plt.scatter(df['GPA'], df['Stress_Level'], color="red")
plt.title("Scatter Plot of GPA vs Stress Level")
plt.xlabel("GPA")
plt.ylabel("Stress Level")

# Display the plots
plt.tight_layout()
plt.show()
# Since the data is for 2000 Students, the scatter plot is like this.
